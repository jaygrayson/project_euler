# %% [markdown]
# # Poker hands
#
# ## Problem 54
#
# In the card game poker, a hand consists of five cards and are ranked, from lowest to highest, in the following way:
#
# 1. High Card: Highest value card.
# 1. One Pair: Two cards of the same value.
# 1. Two Pairs: Two different pairs.
# 1. Three of a Kind: Three cards of the same value.
# 1. Straight: All cards are consecutive values.
# 1. Flush: All cards of the same suit.
# 1. Full House: Three of a kind and a pair.
# 1. Four of a Kind: Four cards of the same value.
# 1. Straight Flush: All cards are consecutive values of same suit.
# 1. Royal Flush: Ten, Jack, Queen, King, Ace, in same suit.
#
# The cards are valued in the order: 2, 3, 4, 5, 6, 7, 8, 9, 10, Jack, Queen, King, Ace.
#
# If two players have the same ranked hands then the rank made up of the highest value wins; for example, a pair of eights beats a pair of fives. But if two ranks tie, for example, both players have a pair of queens, then highest cards in each hand are compared; if the highest cards tie then the next highest cards are compared, and so on.
#
# The file, poker.txt, contains one-thousand random hands dealt to two players. Each line of the file contains ten cards (separated by a single space): the first five are Player 1's cards and the last five are Player 2's cards. You can assume that all hands are valid (no invalid characters or repeated cards), each player's hand is in no specific order, and in each hand there is a clear winner.
#
# How many hands does Player 1 win?

# %% [markdown]
# ## Load hads into MySQL database for practice
#
# Connect to local MySQL database. Create table for each player.

# %%
import MySQLdb as sql

conn = sql.connect(host='localhost', user='jaygrayson', passwd='password', db='projecteuler')

def create_poker_table(conn, name):
    """create mysql table for a player's poker hand, including hand rank and high cards"""
    conn.query('DROP TABLE IF EXISTS '+name)
    conn.query('CREATE TABLE '+name+' (hand INT PRIMARY KEY)')
    conn.query( 'ALTER TABLE '+name+' ADD (card1 INT, card2 INT, card3 INT, card4 INT, card5 INT)')
    conn.query( 'ALTER TABLE '+name+' ADD (suit1 INT, suit2 INT, suit3 INT, suit4 INT, suit5 INT)')
    conn.query( 'ALTER TABLE '+name+' ADD (rank INT)')
    conn.query( 'ALTER TABLE '+name+' ADD (high1 INT, high2 INT, high3 INT, high4 INT, high5 INT)')

create_poker_table(conn, 'pe0054_player1')
create_poker_table(conn, 'pe0054_player2')

# %% [markdown]
# Load txt file in python and populate into the MySQL database...

# %%
import csv

results = [] # load all of text file into list of lists
with open('pe-0054_poker-hands.txt') as inputfile:
    for row in csv.reader(inputfile, delimiter=' '):
        results.append(row)
p1 = []; p2 = []; # split into player 1 and 2's hands
for row in results:
    p1.append(row[0:5])
    p2.append(row[5:10])
    
def load_hands(conn, name, hands)
    """load hands into the database for a player"""
    for hand in hands:
        for card in hand:

# %%
p1
# Out:
# [['8C', 'TS', 'KC', '9H', '4S'],
#  ['5C', 'AD', '5D', 'AC', '9C'],
#  ['3H', '7H', '6S', 'KC', 'JS'],
#  ['TH', '8H', '5C', 'QS', 'TC'],
#  ['7C', '5H', 'KC', 'QH', 'JD'],
#  ['5H', 'KS', '9C', '7D', '9H'],
#  ['6H', '4H', '5C', '3H', '2H'],
#  ['TD', '8C', '4H', '7C', 'TC'],
#  ['7C', '9C', '6D', 'KD', '3H'],
#  ['JC', '6S', '5H', '2H', '2D'],
#  ['AD', 'QH', 'TH', '9D', '8H'],
#  ['2H', '4S', '5C', '5S', 'TC'],
#  ['QD', 'AS', '6H', 'JS', '2C'],
#  ['KD', '8S', '9S', '7C', '2S'],
#  ['3C', '8C', '2D', '7D', '4D'],
#  ['8C', 'KC', '7S', 'TC', '2D'],
#  ['3D', 'KH', 'QD', '6C', '6S'],
#  ['6S', '8D', '4C', '8S', '6C'],
#  ['2S', '8D', '8C', '4C', 'TS'],
#  ['3C', 'QS', '2S', '4H', 'JH'],
#  ['5H', 'QS', '8S', '6D', '3C'],
#  ['6H', 'TD', '9D', 'AS', 'JH'],
#  ['AH', '8S', 'QS', '4D', 'TH'],
#  ['5S', '4D', 'JS', '3D', '8H'],
#  ['6D', '7C', '5D', '5H', '3S'],
#  ['5H', '6H', '2S', 'KS', '3D'],
#  ['KH', '4H', 'AS', 'JS', 'QS'],
#  ['3D', 'QS', 'TS', '2H', 'JS'],
# ...

# %%
import time
import math
import numpy as np

# %%
def isprime(x):
    """return True if number is prime"""
    x = int(x)
    i = 2
    ans = True
    while i <= math.sqrt(x): # test divisibility by 2,3,...,sqrt(x)
        if x % i == 0:
            ans = False
            break
        i = i+1
    return ans

# %%
def primes(n):
    """return list of primes below n"""
    ps = []
    for i in range(2,n):
        if isprime(i):
            ps.append(i)
    return ps

# %%
t1 = time.time() # tic

ps = np.array(primes(int(2e6)))
s = np.sum(ps)

t2 = time.time() # toc
print ''
print 'result:', s
print 'seconds:', t2-t1
# Out:
# result: 142913828922
# seconds: 30.2820339203
